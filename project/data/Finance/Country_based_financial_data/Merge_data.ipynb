# %%
import pandas as pd
import numpy as np

# %%
df_1 = pd.read_csv("Workbook1_pov.csv", delimiter = ",", decimal = ".", index_col = "Country"  )
df_1.head()
# Out:
#             Country Code  \
# Country
# Afghanistan          AFG
# Albania              ALB
# Algeria              DZA
# Angola               AGO
# Argentina            ARG
#
#              2012 [YR2012] - Annualized growth in per capita real survey mean consumption or income, bottom 40% (%) [SI.SPR.PC40.ZG]  \
# Country
# Afghanistan                                                NaN
# Albania                                              -1.220415
# Algeria                                                    NaN
# Angola                                                     NaN
# Argentina                                             6.427386
#
#              2012 [YR2012] - Annualized growth in per capita real survey mean consumption or income, total population (%) [SI.SPR.PCAP.ZG]  \
# Country
# Afghanistan                                                NaN
# Albania                                              -1.314203
# ...

# %%
df_2 = pd.read_csv("Workbook2_wdi.csv", delimiter = ",", decimal = ".", index_col = "Country Name" )
df_2.head()
# Out:
#                Country Code  \
# Country Name
# Afghanistan             AFG
# Albania                 ALB
# Algeria                 DZA
# American Samoa          ASM
# Andorra                 ADO
#
#                 2012 [YR2012] - Long-term unemployment (% of total unemployment) [SL.UEM.LTRM.ZS]  \
# Country Name
# Afghanistan                                                   NaN
# Albania                                                 77.300003
# Algeria                                                       NaN
# American Samoa                                                NaN
# Andorra                                                       NaN
#
#                 2012 [YR2012] - Unemployment, total (% of total labor force) [SL.UEM.TOTL.ZS]  \
# Country Name
# Afghanistan                                                   8.5
# Albania                                                      13.9
# Algeria                                                      11.0
# ...

# %%
df_y = pd.read_csv("y.csv", delimiter = ",", decimal = "." , index_col = "Country" )
df_y.head()
# Out:
#              Overall Rank  Score  Change Over Prior Year  GDP per capita  \
# Country
# Denmark                 1  7.526                  -0.401             NaN
# Switzerland             2  7.509                   0.035             NaN
# Iceland                 3  7.501                   0.000             NaN
# Norway                  4  7.498                   0.082             NaN
# Finland                 5  7.413                  -0.259             NaN
#
#              Social support  Healthy life expectancy  \
# Country
# Denmark                 NaN                      NaN
# Switzerland             NaN                      NaN
# Iceland                 NaN                      NaN
# Norway                  NaN                      NaN
# Finland                 NaN                      NaN
#
#              Freedom to make life choices  Generosity  Trust
# Country
# Denmark                               NaN         NaN    NaN
# ...

# %%
result = pd.concat([df_1, df_2], axis=1, join_axes=[df_y.index])

# %%
result.to_csv("X_Ahmet.csv")
